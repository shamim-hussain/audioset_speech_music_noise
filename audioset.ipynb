# %% [markdown]
# <a href="https://colab.research.google.com/github/shamim-hussain/audioset_speech_music_noise/blob/main/audioset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download

# %%
# !mkdir audioset
# %cd audioset
# !git clone https://github.com/shamim-hussain/audioset_speech_music_noise.git
# %cd audioset_speech_music_noise

# !git clone https://github.com/audioset/ontology

# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/eval_segments.csv
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/balanced_train_segments.csv
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/unbalanced_train_segments.csv
# Out:
# Cloning into 'audioset_speech_music_noise'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.
# /content/audioset_speech_music_noise
# Cloning into 'ontology'...
# remote: Enumerating objects: 14, done.
# remote: Total 14 (delta 0), reused 0 (delta 0), pack-reused 14
# Unpacking objects: 100% (14/14), done.
# --2021-10-18 22:22:03--  http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/eval_segments.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.203.128, 172.253.123.128, 108.177.13.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.203.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1143389 (1.1M) [text/csv]
# Saving to: ‘eval_segments.csv’
#
# ...

# %% [markdown]
# # Build Superclasses

# %% [markdown]
# ## Load ontology

# %%
import pandas as pd
import numpy as np

df_onto = pd.read_json('ontology/ontology.json')
df_onto.head()
# Out:
#           id  ... restrictions
# 0  /m/0dgw9r  ...   [abstract]
# 1   /m/09l8g  ...   [abstract]
# 2   /m/09x0r  ...           []
# 3  /m/05zppz  ...           []
# 4   /m/02zsn  ...           []
#
# [5 rows x 7 columns]

# %% [markdown]
# Set id as index.

# %%
df_onto.set_index('id',inplace=True)
df_onto
# Out:
#                                     name  ... restrictions
# id                                        ...
# /m/0dgw9r                   Human sounds  ...   [abstract]
# /m/09l8g                     Human voice  ...   [abstract]
# /m/09x0r                          Speech  ...           []
# /m/05zppz      Male speech, man speaking  ...           []
# /m/02zsn   Female speech, woman speaking  ...           []
# ...                                  ...  ...          ...
# /m/025l19                      Recording  ...  [blacklist]
# /m/07hvw1                Field recording  ...  [blacklist]
# /m/0174nj              Gramophone record  ...  [blacklist]
# /m/01www                    Compact disc  ...  [blacklist]
# /m/04zc0                             MP3  ...  [blacklist]
#
# [632 rows x 6 columns]

# %% [markdown]
# ## View Main Classes

# %% [markdown]
# Speech

# %%
id_speech = r'/m/09x0r'
df_onto.loc[id_speech]
# Out:
# name                                                            Speech
# description          Speech is the vocalized form of human communic...
# citation_uri                       http://en.wikipedia.org/wiki/Speech
# positive_examples    [youtu.be/8uI9H5jGRV8?start=30&end=40, youtu.b...
# child_ids            [/m/05zppz, /m/02zsn, /m/0ytgt, /m/01h8n0, /m/...
# restrictions                                                        []
# Name: /m/09x0r, dtype: object

# %% [markdown]
# Music

# %%
id_music = r'/m/04rlf'
df_onto.loc[id_music]
# Out:
# name                                                             Music
# description          Music is an art form and cultural activity who...
# citation_uri                        http://en.wikipedia.org/wiki/Music
# positive_examples    [youtu.be/E83fRA1wxKU?start=420&end=430, youtu...
# child_ids            [/m/04szw, /m/0kpv1t, /t/dd00027, /t/dd00028, ...
# restrictions                                                        []
# Name: /m/04rlf, dtype: object

# %% [markdown]
# Human Sound

# %%
id_human = r'/m/0dgw9r'
df_onto.loc[id_human]
# Out:
# name                                                      Human sounds
# description          Sounds produced by the human body through the ...
# citation_uri
# positive_examples                                                   []
# child_ids            [/m/09l8g, /m/01w250, /m/09hlz4, /m/0bpl036, /...
# restrictions                                                [abstract]
# Name: /m/0dgw9r, dtype: object

# %% [markdown]
# ### Child Classes

# %% [markdown]
# Speech

# %%
print(f'Speech: Total {len(df_onto.loc[id_speech])} child classes\n')
for i, id in enumerate(df_onto.loc[id_speech].child_ids):
    print(f'[{i+1}]')
    print(df_onto.loc[id])
    print()
# Out:
# Speech: Total 6 child classes
#
# [1]
# name                                         Male speech, man speaking
# description                     Speech uttered by an adult male human.
# citation_uri
# positive_examples    [youtu.be/6niRPYpLOpQ?start=30&end=40, youtu.b...
# child_ids                                                           []
# restrictions                                                        []
# Name: /m/05zppz, dtype: object
#
# [2]
# name                                     Female speech, woman speaking
# description                   Speech uttered by an adult female human.
# citation_uri
# positive_examples    [youtu.be/4l05nCOnIRg?start=30&end=40, youtu.b...
# child_ids                                                           []
# restrictions                                                        []
# Name: /m/02zsn, dtype: object
#
# [3]
# name                                        Child speech, kid speaking
# ...

# %% [markdown]
# Music

# %%
print(f'Music: Total {len(df_onto.loc[id_music])} child classes\n')
for i, id in enumerate(df_onto.loc[id_music].child_ids):
    print(f'[{i+1}]')
    print(df_onto.loc[id])
    print()
# Out:
# Music: Total 6 child classes
#
# [1]
# name                                                Musical instrument
# description          Sounds specifically associated with instrument...
# citation_uri           http://en.wikipedia.org/wiki/Musical_instrument
# positive_examples    [youtu.be/7umb9yJpkKU?start=70&end=80, youtu.b...
# child_ids            [/m/0fx80y, /m/05148p4, /m/0l14md, /m/05pd6, /...
# restrictions                                                        []
# Name: /m/04szw, dtype: object
#
# [2]
# name                                                       Music genre
# description          Portmanteau class holding categories that repr...
# citation_uri
# positive_examples                                                   []
# child_ids            [/m/064t9, /m/0glt670, /m/06by7, /m/06j6l, /m/...
# restrictions                                                [abstract]
# Name: /m/0kpv1t, dtype: object
#
# [3]
# ...

# %% [markdown]
# Human Sounds

# %%
print(f'Human sounds: Total {len(df_onto.loc[id_human])} child classes\n')
for i, id in enumerate(df_onto.loc[id_human].child_ids):
    print(f'[{i+1}]')
    print(df_onto.loc[id])
    print()
# Out:
# Human sounds: Total 6 child classes
#
# [1]
# name                                                       Human voice
# description          The human voice consists of sound made by a hu...
# citation_uri                  http://en.wikipedia.org/wiki/Human_voice
# positive_examples                                                   []
# child_ids            [/m/09x0r, /m/07p6fty, /m/03qc9zr, /m/02rtxlg,...
# restrictions                                                [abstract]
# Name: /m/09l8g, dtype: object
#
# [2]
# name                                                         Whistling
# description          High-pitched tone produced by blowing or sucki...
# citation_uri                    http://en.wikipedia.org/wiki/Whistling
# positive_examples    [youtu.be/MJJv-SQVbQY?start=140&end=150, youtu...
# child_ids                                                  [/m/079vc8]
# restrictions                                                        []
# Name: /m/01w250, dtype: object
#
# ...

# %%
print(f'Human voice sounds: Total {len(df_onto.loc["/m/09l8g"])} child classes\n')
for i, id in enumerate(df_onto.loc['/m/09l8g'].child_ids):
    print(f'[{i+1}]')
    print(df_onto.loc[id])
    print()
# Out:
# Human voice sounds: Total 6 child classes
#
# [1]
# name                                                            Speech
# description          Speech is the vocalized form of human communic...
# citation_uri                       http://en.wikipedia.org/wiki/Speech
# positive_examples    [youtu.be/8uI9H5jGRV8?start=30&end=40, youtu.b...
# child_ids            [/m/05zppz, /m/02zsn, /m/0ytgt, /m/01h8n0, /m/...
# restrictions                                                        []
# Name: /m/09x0r, dtype: object
#
# [2]
# name                                                             Shout
# description          Talk in a loud voice to deliberately command a...
# citation_uri         http://wordnetweb.princeton.edu/perl/webwn?s=s...
# positive_examples    [youtu.be/-aY64NxBVas?start=480&end=490, youtu...
# child_ids            [/m/07q4ntr, /m/07rwj3x, /m/07sr1lc, /m/04gy_2...
# restrictions                                                        []
# ...

# %% [markdown]
# ### Superclasses

# %%
def get_all_subclasses(lb):
    lst=[]
    lst.append(lb)
    for c in df_onto.loc[lb,'child_ids']:
        lst.extend(get_all_subclasses(c))
    return lst

speech_classes = get_all_subclasses(id_speech)
music_classes = get_all_subclasses(id_music)
human_classes = get_all_subclasses(id_human)

noise_classes = list(cls for cls in df_onto.index if cls not in human_classes and cls not in music_classes)

# %%
print('Speech Classes:\n')
for cls in speech_classes:
    print(df_onto.loc[cls,'name'])
# Out:
# Speech Classes:
#
# Speech
# Male speech, man speaking
# Female speech, woman speaking
# Child speech, kid speaking
# Conversation
# Narration, monologue
# Babbling
# Speech synthesizer

# %%
print('Music Classes:\n')
for cls in music_classes:
    print(df_onto.loc[cls,'name'])

print()
# Out:
# Music Classes:
#
# Music
# Musical instrument
# Plucked string instrument
# Guitar
# Electric guitar
# Bass guitar
# Acoustic guitar
# Steel guitar, slide guitar
# Tapping (guitar technique)
# Strum
# Banjo
# Sitar
# Mandolin
# Zither
# Ukulele
# Keyboard (musical)
# Piano
# Electric piano
# Clavinet
# Rhodes piano
# Organ
# Electronic organ
# Hammond organ
# Synthesizer
# Sampler
# Mellotron
# Harpsichord
# Percussion
# Drum kit
# Drum machine
# Drum
# Snare drum
# Rimshot
# Drum roll
# Bass drum
# Timpani
# Tabla
# Cymbal
# Hi-hat
# Crash cymbal
# Cowbell
# Wood block
# Tambourine
# Rattle (instrument)
# Maraca
# Gong
# Tubular bells
# Mallet percussion
# Marimba, xylophone
# Glockenspiel
# Vibraphone
# Steelpan
# Orchestra
# Brass instrument
# French horn
# Trumpet
# Trombone
# Cornet
# Bugle
# Bowed string instrument
# String section
# Violin, fiddle
# Pizzicato
# Cello
# Double bass
# Wind instrument, woodwind instrument
# Flute
# Saxophone
# Alto saxophone
# Soprano saxophone
# ...

# %%
print('Human sound Classes:\n')
for cls in human_classes:
    print(df_onto.loc[cls,'name'])
# Out:
# Human sound Classes:
#
# Human sounds
# Human voice
# Speech
# Male speech, man speaking
# Female speech, woman speaking
# Child speech, kid speaking
# Conversation
# Narration, monologue
# Babbling
# Speech synthesizer
# Shout
# Bellow
# Whoop
# Yell
# Battle cry
# Children shouting
# Screaming
# Whispering
# Laughter
# Baby laughter
# Giggle
# Snicker
# Belly laugh
# Chuckle, chortle
# Crying, sobbing
# Baby cry, infant cry
# Whimper
# Wail, moan
# Sigh
# Singing
# Choir
# Yodeling
# Chant
# Mantra
# Male singing
# Female singing
# Child singing
# Synthetic singing
# Rapping
# Humming
# Groan
# Grunt
# Yawn
# Whistling
# Wolf-whistling
# Respiratory sounds
# Breathing
# Wheeze
# Snoring
# Gasp
# Pant
# Snort
# Cough
# Throat clearing
# Sneeze
# Sniff
# Human locomotion
# Run
# Shuffle
# Walk, footsteps
# Digestive
# Chewing, mastication
# Biting
# Gargling
# Stomach rumble
# Burping, eructation
# Hiccup
# Fart
# Hands
# Finger snapping
# Clapping
# Heart sounds, heartbeat
# ...

# %%
print('Noise Classes:\n')
for cls in noise_classes:
    print(df_onto.loc[cls,'name'])
# Out:
# Noise Classes:
#
# Animal
# Domestic animals, pets
# Dog
# Bark
# Yip
# Howl
# Bow-wow
# Growling
# Whimper (dog)
# Bay
# Cat
# Purr
# Meow
# Hiss
# Cat communication
# Caterwaul
# Livestock, farm animals, working animals
# Horse
# Clip-clop
# Neigh, whinny
# Snort (horse)
# Nicker
# Donkey, ass
# Cattle, bovinae
# Moo
# Yak
# Pig
# Oink
# Goat
# Bleat
# Sheep
# Fowl
# Chicken, rooster
# Cluck
# Crowing, cock-a-doodle-doo
# Turkey
# Gobble
# Duck
# Quack
# Goose
# Honk
# Wild animals
# Roaring cats (lions, tigers)
# Roar
# Bird
# Bird vocalization, bird call, bird song
# Chirp, tweet
# Squawk
# Pigeon, dove
# Coo
# Crow
# Caw
# Owl
# Hoot
# Gull, seagull
# Bird flight, flapping wings
# Canidae, dogs, wolves
# Rodents, rats, mice
# Mouse
# Chipmunk
# Patter
# Insect
# Cricket
# Mosquito
# Fly, housefly
# Buzz
# Bee, wasp, etc.
# Frog
# Croak
# Snake
# Rattle
# Whale vocalization
# Natural sounds
# Wind
# Howl (wind)
# Rustling leaves
# Wind noise (microphone)
# Thunderstorm
# Thunder
# ...

# %% [markdown]
# ### Test exclusivity

# %%
assert len(set(speech_classes).intersection(set(music_classes))) == 0
assert len(set(speech_classes).intersection(set(noise_classes))) == 0
assert len(set(noise_classes).intersection(set(music_classes))) == 0

# %% [markdown]
# ### Save

# %%
def get_superclass(cls):
    cls
    if cls in speech_classes:
        return 'speech'
    elif cls in music_classes:
        return 'music'
    elif cls in noise_classes:
        return 'noise'
    else:
        return 'nonspeech_human_sound'

df_onto['superclass']=list(map(get_superclass, df_onto.index))
df_onto
# Out:
#                                     name  ...             superclass
# id                                        ...
# /m/0dgw9r                   Human sounds  ...  nonspeech_human_sound
# /m/09l8g                     Human voice  ...  nonspeech_human_sound
# /m/09x0r                          Speech  ...                 speech
# /m/05zppz      Male speech, man speaking  ...                 speech
# /m/02zsn   Female speech, woman speaking  ...                 speech
# ...                                  ...  ...                    ...
# /m/025l19                      Recording  ...                  noise
# /m/07hvw1                Field recording  ...                  noise
# /m/0174nj              Gramophone record  ...                  noise
# /m/01www                    Compact disc  ...                  noise
# /m/04zc0                             MP3  ...                  noise
#
# [632 rows x 7 columns]

# %%
import os
os.makedirs('processed',exist_ok=True)

df_onto.to_pickle('processed/ontology_with_superclass.pkl')
# df_onto.reset_index().to_json('processed/ontology_with_superclass.json',orient='records', indent=4)

# %% [markdown]
# Optionally save superclasses

# %%
import yaml
super_classes = dict(
    speech = list({'id':id, 'name':df_onto.loc[id,'name']} for id in speech_classes),
    music = list({'id':id, 'name':df_onto.loc[id,'name']} for id in music_classes),
    noise = list({'id':id, 'name':df_onto.loc[id,'name']} for id in noise_classes),
    human = list({'id':id, 'name':df_onto.loc[id,'name']} for id in human_classes),
)

with open('processed/superclasses.yaml', 'w') as file:
    yaml.dump(super_classes, file)

# %% [markdown]
# # Apply superclass and combine datasets

# %% [markdown]
# ## Load data

# %% [markdown]
# Optionally load ontology with superclass

# %%
import pandas as pd
import numpy as np

df_onto = pd.read_pickle('processed/ontology_with_superclass.pkl')

# %% [markdown]
# Check csv file contents

# %%
with open('eval_segments.csv','r') as file:
    for i, line in zip(range(10), file):
        print(line)
# Out:
# # Segments csv created Sun Mar  5 10:54:25 2017
#
# # num_ytids=20371, num_segs=20371, num_unique_labels=527, num_positive_labels=51804
#
# # YTID, start_seconds, end_seconds, positive_labels
#
# --4gqARaEJE, 0.000, 10.000, "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"
#
# --BfvyPmVMo, 20.000, 30.000, "/m/03l9g"
#
# --U7joUcTCo, 0.000, 10.000, "/m/01b_21"
#
# --i-y1v8Hy8, 0.000, 9.000, "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"
#
# -0BIyqJj9ZU, 30.000, 40.000, "/m/07rgt08,/m/07sq110,/t/dd00001"
#
# -0CamVQdP_Y, 0.000, 6.000, "/m/04rlf,/m/07pbtc8,/m/09x0r"
#
# -0Gj8-vB1q4, 30.000, 40.000, "/m/0140xf,/m/02cjck,/m/04rlf"

# %%
df_eval = pd.read_csv('eval_segments.csv', sep=', ', engine ='python', skiprows=2)
df_balanced = pd.read_csv('balanced_train_segments.csv', sep=', ', engine ='python', skiprows=2)
df_unbalanced = pd.read_csv('unbalanced_train_segments.csv', sep=', ', engine ='python', skiprows=2)
df_eval
# Out:
#             # YTID  ...                            positive_labels
# 0      --4gqARaEJE  ...    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"
# 1      --BfvyPmVMo  ...                                 "/m/03l9g"
# 2      --U7joUcTCo  ...                                "/m/01b_21"
# 3      --i-y1v8Hy8  ...  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"
# 4      -0BIyqJj9ZU  ...         "/m/07rgt08,/m/07sq110,/t/dd00001"
# ...            ...  ...                                        ...
# 20366  zyF8TGSRvns  ...   "/m/0dwsp,/m/0dwtp,/m/0f8s22,/m/0j45pbj"
# 20367  zz35Va7tYmA  ...  "/m/012f08,/m/07q2z82,/m/07qmpdm,/m/0k4j"
# 20368  zzD_oVgzKMc  ...                               "/m/07pn_8q"
# 20369  zzNdwF40ID8  ...                        "/m/04rlf,/m/0790c"
# 20370  zzbTaK7CXJY  ...         "/m/03m9d0z,/m/07qwyj0,/t/dd00092"
#
# [20371 rows x 4 columns]

# %% [markdown]
# ## Combine

# %%
df_eval['dataset_split'] = 'eval'
df_balanced['dataset_split'] = 'train_balanced'
df_unbalanced['dataset_split'] = 'train_unbalanced'

df_audioset = pd.concat([df_eval,df_balanced,df_unbalanced])
df_audioset
# Out:
#               # YTID  ...     dataset_split
# 0        --4gqARaEJE  ...              eval
# 1        --BfvyPmVMo  ...              eval
# 2        --U7joUcTCo  ...              eval
# 3        --i-y1v8Hy8  ...              eval
# 4        -0BIyqJj9ZU  ...              eval
# ...              ...  ...               ...
# 2041784  zzyyleHsxfk  ...  train_unbalanced
# 2041785  zzz-JsGPtxQ  ...  train_unbalanced
# 2041786  zzz3PZXRQ_8  ...  train_unbalanced
# 2041787  zzznDcamMpw  ...  train_unbalanced
# 2041788  zzztDPePp4g  ...  train_unbalanced
#
# [2084320 rows x 5 columns]

# %% [markdown]
# ## Assign superclasses

# %%
onto_super = df_onto.superclass
def get_plausible_superclass(labels):
    labels = labels[1:-1].split(',')
    supers = set(onto_super[lb] for lb in labels)
    if len(supers) == 1:
        super_cls ,= supers
    else:
        super_cls = 'other'
    return super_cls 

df_audioset['plausible_superclass'] = df_audioset.positive_labels.apply(get_plausible_superclass)
df_audioset
# Out:
#               # YTID  start_seconds  ...     dataset_split   plausible_superclass
# 0        --4gqARaEJE            0.0  ...              eval                  noise
# 1        --BfvyPmVMo           20.0  ...              eval                  noise
# 2        --U7joUcTCo            0.0  ...              eval  nonspeech_human_sound
# 3        --i-y1v8Hy8            0.0  ...              eval                  other
# 4        -0BIyqJj9ZU           30.0  ...              eval  nonspeech_human_sound
# ...              ...            ...  ...               ...                    ...
# 2041784  zzyyleHsxfk           20.0  ...  train_unbalanced                  noise
# 2041785  zzz-JsGPtxQ          120.0  ...  train_unbalanced                  other
# 2041786  zzz3PZXRQ_8           30.0  ...  train_unbalanced                  other
# 2041787  zzznDcamMpw            0.0  ...  train_unbalanced                  other
# ...

# %% [markdown]
# Rename columns and reindex

# %%
df_audioset.columns = ['ytid'] + list(df_audioset.columns[1:])
df_audioset.set_index('ytid',inplace=True)
df_audioset
# Out:
#              start_seconds  ...   plausible_superclass
# ytid                        ...
# --4gqARaEJE            0.0  ...                  noise
# --BfvyPmVMo           20.0  ...                  noise
# --U7joUcTCo            0.0  ...  nonspeech_human_sound
# --i-y1v8Hy8            0.0  ...                  other
# -0BIyqJj9ZU           30.0  ...  nonspeech_human_sound
# ...                    ...  ...                    ...
# zzyyleHsxfk           20.0  ...                  noise
# zzz-JsGPtxQ          120.0  ...                  other
# zzz3PZXRQ_8           30.0  ...                  other
# zzznDcamMpw            0.0  ...                  other
# zzztDPePp4g          410.0  ...                  other
#
# [2084320 rows x 5 columns]

# %% [markdown]
# Count plausible superclasses

# %%
print('eval:')
print(df_audioset[df_audioset.dataset_split=='eval'].plausible_superclass.value_counts())
print()

print('train_balanced:')
print(df_audioset[df_audioset.dataset_split=='train_balanced'].plausible_superclass.value_counts())
print()

print('train_unbalanced:')
print(df_audioset[df_audioset.dataset_split=='train_unbalanced'].plausible_superclass.value_counts())
print()

print('overall:')
print(df_audioset.plausible_superclass.value_counts())
# Out:
# eval:
# other                    7724
# noise                    7499
# music                    4095
# nonspeech_human_sound     934
# speech                    119
# Name: plausible_superclass, dtype: int64
#
# train_balanced:
# other                    8161
# noise                    7808
# music                    5036
# nonspeech_human_sound     965
# speech                    190
# Name: plausible_superclass, dtype: int64
#
# train_unbalanced:
# other                    649774
# music                    633101
# speech                   470036
# noise                    266295
# nonspeech_human_sound     22583
# Name: plausible_superclass, dtype: int64
#
# overall:
# other                    665659
# music                    642232
# speech                   470345
# noise                    281602
# nonspeech_human_sound     24482
# Name: plausible_superclass, dtype: int64

# %% [markdown]
# ### Save

# %%
import os
os.makedirs('processed',exist_ok=True)

# df_audioset.to_pickle('processed/audioset_with_superclass.pkl')
df_audioset.reset_index().to_json('processed/audioset_with_superclass.json.gz',orient='records',indent=4)

# %% [markdown]
# # Add Annotations

# %% [markdown]
# ## Load

# %%
import pandas as pd

df_audioset = pd.read_json('processed/audioset_with_superclass.json.gz')
df_audioset.set_index('ytid',inplace=True)
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
# ...                    ...          ...
# zzyyleHsxfk           20.0         30.0
# zzz-JsGPtxQ          120.0        130.0
# zzz3PZXRQ_8           30.0         40.0
# zzznDcamMpw            0.0         10.0
# zzztDPePp4g          410.0        420.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# --U7joUcTCo                                "/m/01b_21"              eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"              eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"              eval
# ...

# %%
df_anno = pd.read_json('processed/annotations_4k.json.gz')
df_anno.set_index('ytid',inplace=True)
df_anno
# Out:
#             checked_superclass check_status     dataset_split  \
# ytid
# -Ib9SQDZIXs             speech          bad  train_unbalanced
# -IbwO3Y3ojk             speech          bad  train_unbalanced
# -IdD4kUUlZc             speech          bad  train_unbalanced
# -IdoJfU9HvM             speech          bad  train_unbalanced
# -IdUjFF-tzo             speech          bad  train_unbalanced
# ...                        ...          ...               ...
# QZpgHrKXooc              noise         good              eval
# QZvhpLzzg-0              noise         good              eval
# QZwRv64XNfM              noise         good              eval
# Q_irhm3HCQw              noise         good              eval
# Q_yoAT1Z3Yw              noise         good              eval
#
#                                                      file_path  \
# ytid
# -Ib9SQDZIXs  D:\Audioset_unbalanced_wav2\Speech\Bad\-Ib9SQD...
# -IbwO3Y3ojk  D:\Audioset_unbalanced_wav2\Speech\Bad\-IbwO3Y...
# ...

# %%
print(df_anno.check_status.value_counts())
print()
print(df_anno.groupby('checked_superclass').apply(lambda x:x.check_status.value_counts()))
# Out:
# unchecked    24064
# good         12064
# bad           5061
# Name: check_status, dtype: int64
#
# checked_superclass
# music               unchecked     4333
#                     good          3996
#                     bad            981
# noise               unchecked     4995
#                     good          4032
#                     bad           1347
# other               unchecked    14213
# speech              good          4036
#                     bad           2733
#                     unchecked      523
# Name: check_status, dtype: int64

# %%
print(df_anno.groupby(['checked_superclass','dataset_split']).apply(lambda x:x.check_status.value_counts()))
# Out:
# checked_superclass  dataset_split
# music               eval              good          988
#                                       bad           311
#                     train_balanced    good         3008
#                                       bad           670
#                     train_unbalanced  unchecked    4333
# noise               eval              good         2478
#                                       bad           800
#                     train_balanced    unchecked    3752
#                                       good         1554
#                                       bad           547
#                     train_unbalanced  unchecked    1243
# other               eval              unchecked    3518
#                     train_balanced    unchecked    6588
#                     train_unbalanced  unchecked    4107
# speech              eval              good           34
#                                       bad            18
# ...

# %%
assert df_audioset.index.is_unique
assert df_anno.index.is_unique

assert set(df_anno.index).issubset(set(df_audioset.index))
assert (df_anno.dataset_split == df_audioset.loc[df_anno.index, 'dataset_split']).all()

# %%
mistmatch=(df_anno.checked_superclass != df_audioset.loc[df_anno.index, 'plausible_superclass'])
df_anno.checked_superclass[mistmatch].value_counts()
# Out:
# other    1218
# Name: checked_superclass, dtype: int64

# %% [markdown]
# ## Merge annotations

# %%
df_audioset['download_status'] = False
df_audioset.loc[df_anno.index,'download_status'] = True
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
# ...                    ...          ...
# zzyyleHsxfk           20.0         30.0
# zzz-JsGPtxQ          120.0        130.0
# zzz3PZXRQ_8           30.0         40.0
# zzznDcamMpw            0.0         10.0
# zzztDPePp4g          410.0        420.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# --U7joUcTCo                                "/m/01b_21"              eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"              eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"              eval
# ...

# %%
df_audioset['check_status'] = 'unchecked'
df_audioset.loc[df_anno.index,'check_status'] = df_anno.check_status
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
# ...                    ...          ...
# zzyyleHsxfk           20.0         30.0
# zzz-JsGPtxQ          120.0        130.0
# zzz3PZXRQ_8           30.0         40.0
# zzznDcamMpw            0.0         10.0
# zzztDPePp4g          410.0        420.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# --U7joUcTCo                                "/m/01b_21"              eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"              eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"              eval
# ...

# %%
print(df_audioset[df_audioset.download_status].groupby(['plausible_superclass','dataset_split']).apply(lambda x:x.check_status.value_counts()))
# Out:
# plausible_superclass   dataset_split
# music                  eval              good          988
#                                          bad           311
#                        train_balanced    good         3008
#                                          bad           670
#                        train_unbalanced  unchecked    4333
# noise                  eval              good         2478
#                                          bad           800
#                        train_balanced    unchecked    3752
#                                          good         1554
#                                          bad           547
#                        train_unbalanced  unchecked    1243
# nonspeech_human_sound  eval              unchecked     387
#                        train_balanced    unchecked     672
#                        train_unbalanced  unchecked     159
# other                  eval              unchecked    3131
# ...

# %%
print(df_audioset.groupby(['plausible_superclass','dataset_split']).apply(lambda x:x.download_status.value_counts()))
# Out:
# plausible_superclass   dataset_split
# music                  eval              False      2796
#                                          True       1299
#                        train_balanced    True       3678
#                                          False      1358
#                        train_unbalanced  False    628768
#                                          True       4333
# noise                  eval              False      4221
#                                          True       3278
#                        train_balanced    True       5853
#                                          False      1955
#                        train_unbalanced  False    265052
#                                          True       1243
# nonspeech_human_sound  eval              False       547
#                                          True        387
#                        train_balanced    True        672
#                                          False       293
# ...

# %% [markdown]
# ## Save

# %%
df_audioset.reset_index().to_json('processed/audioset_annot_4k.json.gz',orient='records',indent=4)

# %% [markdown]
# # Add new downloads

# %%
from pathlib import Path
source_paths = list(Path(p) for p in [
                      'I:\\Audioset\\Audioset_eval_wav',
                      'I:\\Audioset\\Audioset_eval_wav2',
                      'I:\\Audioset\\Audioset_train_wav',
                      'I:\\Audioset\\Audioset_train_wav2',
                      'I:\\Audioset\\Audioset_unbalanced_wav',
                      'I:\\Audioset\\Audioset_unbalanced_wav2',
                      ])
source_file_paths = list(f for p in source_paths for f in p.rglob('*.wav'))
destination_path = Path('G:\\datasets\\audioset')

# %%
print(len(source_file_paths))
print(df_audioset.download_status.sum())
# Out:
# 46093
# 41189

# %%
source_file_paths[0].name[:11]
# Out:
# '-0YUDn-1yII'

# %%
ytids = set(p.name[:11] for p in source_file_paths)
assert ytids.issubset(set(df_audioset.index))

# %%
sum(df_audioset.loc[i,'download_status'] for i in ytids)
# Out:
# 41189

# %%
new = list(i for i in ytids if not df_audioset.loc[i,'download_status'])
len(new)
# Out:
# 4904

# %%
df_audioset.loc[new].plausible_superclass.value_counts()
# Out:
# music                    1613
# other                    1498
# speech                   1210
# noise                     510
# nonspeech_human_sound      73
# Name: plausible_superclass, dtype: int64

# %%
import json

with open('processed/new_downloads.json','w') as file:
    json.dump(new, file)

# %%
df_audioset.loc[new,'download_status'] = True
print(df_audioset.download_status.sum())
# Out:
# 46093

# %%
df_audioset.reset_index().to_json('processed/audioset_annot_4k.json.gz',orient='records',indent=4)

# %% [markdown]
# # Copy files

# %%
from pathlib import Path
source_paths = list(Path(p) for p in [
                      'I:\\Audioset\\Audioset_eval_wav',
                      'I:\\Audioset\\Audioset_eval_wav2',
                      'I:\\Audioset\\Audioset_train_wav',
                      'I:\\Audioset\\Audioset_train_wav2',
                      'I:\\Audioset\\Audioset_unbalanced_wav',
                      'I:\\Audioset\\Audioset_unbalanced_wav2',
                      ])
source_file_paths = list(f for p in source_paths for f in p.rglob('*.wav'))
destination_path = Path('G:\\datasets\\audioset')

# %%
df_down = df_audioset[df_audioset.download_status]
df_down = df_down[df_down.plausible_superclass.isin(['speech','music','noise'])]
df_down = df_down.copy()
df_down
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# QY_YNmYjUS8           30.0         40.0
# QY_bTtoO0-c           30.0         40.0
# QY_fLOyPXD4          200.0        210.0
# QYaYLDEMarw           30.0         40.0
# QYbYwTz1ytA          100.0        110.0
#
#                                      positive_labels     dataset_split  \
# ytid
# --4gqARaEJE  "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                               "/m/03l9g"              eval
# -0Gj8-vB1q4           "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                      "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                     "/m/02cjck,/m/04rlf"              eval
# ...

# %%
df_down['source_path'] = pd.Series(dict((p.name[:11],str(p)) for p in source_file_paths))

# %%
df_down.source_path.str[20:]
# Out:
# ytid
# --4gqARaEJE           _eval_wav\Noise\Good\--4gqARaEJE_0.000.wav
# --BfvyPmVMo          _eval_wav\Noise\Good\--BfvyPmVMo_20.000.wav
# -0Gj8-vB1q4          _eval_wav\Music\Good\-0Gj8-vB1q4_30.000.wav
# -0RWZT-miFs          _eval_wav\Noise\Bad\-0RWZT-miFs_420.000.wav
# -0YUDn-1yII           _eval_wav\Music\Bad\-0YUDn-1yII_30.000.wav
#                                      ...
# QY_YNmYjUS8    _unbalanced_wav2\Speech\Unchecked\QY_YNmYjUS8_...
# QY_bTtoO0-c    _unbalanced_wav2\Speech\Unchecked\QY_bTtoO0-c_...
# QY_fLOyPXD4    _unbalanced_wav2\Speech\Unchecked\QY_fLOyPXD4_...
# QYaYLDEMarw    _unbalanced_wav2\Speech\Unchecked\QYaYLDEMarw_...
# QYbYwTz1ytA    _unbalanced_wav2\Speech\Unchecked\QYbYwTz1ytA_...
# Name: source_path, Length: 30309, dtype: object

# %%
df_down['destination_path'] = df_down.apply(lambda x: str(destination_path/x.check_status/x.dataset_split/x.plausible_superclass/x.name)+'.wav',axis=1)
df_down
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# QY_YNmYjUS8           30.0         40.0
# QY_bTtoO0-c           30.0         40.0
# QY_fLOyPXD4          200.0        210.0
# QYaYLDEMarw           30.0         40.0
# QYbYwTz1ytA          100.0        110.0
#
#                                      positive_labels     dataset_split  \
# ytid
# --4gqARaEJE  "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                               "/m/03l9g"              eval
# -0Gj8-vB1q4           "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                      "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                     "/m/02cjck,/m/04rlf"              eval
# ...

# %%
from tqdm import tqdm
import os
import shutil

for _, row in tqdm(df_down.iterrows()):
    os.makedirs(os.path.dirname(row.destination_path),exist_ok=True)
    shutil.copy(row.source_path, row.destination_path)
# Out:
# 30309it [14:14, 35.47it/s]

# %%
df_down.reset_index().to_json('processed/copied.json.gz',orient='records',indent=4)

# %% [markdown]
# # Get Downloadable Files

# %% [markdown]
# # Copy files Again

# %%
import pandas as pd
df_audioset = pd.read_json('processed/audioset_annot_4k.json.gz').set_index('ytid')
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
# ...                    ...          ...
# zzyyleHsxfk           20.0         30.0
# zzz-JsGPtxQ          120.0        130.0
# zzz3PZXRQ_8           30.0         40.0
# zzznDcamMpw            0.0         10.0
# zzztDPePp4g          410.0        420.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# --U7joUcTCo                                "/m/01b_21"              eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"              eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"              eval
# ...

# %%
from pathlib import Path
source_paths = list(Path(p) for p in [
                      'E:\\Dataspace\\Audioset\\train_unbalanced_0\\down_train_unbalanced_0'
                      ])
source_file_paths = list(f for p in source_paths for f in p.rglob('*.wav.gz'))
destination_path = Path('G:\\datasets\\audioset_unchecked')
len(source_file_paths)
# Out:
# 31508

# %%
duplicate_file_paths = list(f for p in source_paths for f in p.rglob('*).gz'))
len(duplicate_file_paths)
# Out:
# 2162

# %%
move_duplicates_folder = Path('E:\\Dataspace\\Audioset\\train_unbalanced_0\\duplicates')
move_duplicates_folder.mkdir()

for p in duplicate_file_paths:
    p.rename(move_duplicates_folder/p.name)

# %%
wav_file_paths = list(f for p in source_paths for f in p.rglob('*.wav'))

all(Path(str(f)+'.gz').exists() for f in wav_file_paths)
# Out:
# True

# %%
new_downloads = pd.Series(dict((p.name[:11],str(p)) for p in source_file_paths))
new_downloads
# Out:
# -a2reKzNEjU    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# -a7bYYC9a44    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# -aaH3I2LHic    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# -aatIwCzLvs    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# -aCz3Bw0erQ    E:\Dataspace\Audioset\train_unbalanced_0\down_...
#                                      ...
# __Hm8xZ5LkM    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# __k7bq0cOoI    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# __MxRgYZjSo    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# __qm75sFhZ4    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# ___lQJ20o4k    E:\Dataspace\Audioset\train_unbalanced_0\down_...
# Length: 31508, dtype: object

# %%
df_down = df_audioset.loc[new_downloads.index]
df_down = df_down.copy()
df_down
# Out:
#              start_seconds  end_seconds               positive_labels  \
# -a2reKzNEjU           30.0         40.0          "/m/04rlf,/m/0l14gg"
# -a7bYYC9a44            0.0         10.0                    "/m/04rlf"
# -aaH3I2LHic           30.0         40.0                    "/m/04rlf"
# -aatIwCzLvs           30.0         40.0  "/m/0342h,/m/04rlf,/m/04szw"
# -aCz3Bw0erQ           19.0         29.0           "/m/04rlf,/m/0m0jc"
# ...                    ...          ...                           ...
# __Hm8xZ5LkM          240.0        250.0                    "/m/09x0r"
# __k7bq0cOoI           30.0         40.0                    "/m/09x0r"
# __MxRgYZjSo           30.0         40.0                    "/m/09x0r"
# __qm75sFhZ4           10.0         20.0           "/m/04rlf,/m/0g293"
# ___lQJ20o4k           30.0         40.0                    "/m/0c1dj"
#
#                 dataset_split plausible_superclass  download_status  \
# ...

# %%
df_down.plausible_superclass.value_counts()
# Out:
# music     14609
# speech    10538
# noise      6361
# Name: plausible_superclass, dtype: int64

# %%
df_audioset[(df_audioset.check_status=='unchecked') & (df_audioset.download_status)].plausible_superclass.value_counts()
# Out:
# other                    14493
# music                     5946
# noise                     5505
# speech                    1733
# nonspeech_human_sound     1291
# Name: plausible_superclass, dtype: int64

# %%
df_audioset.loc[df_down.index,'download_status'] = True

# %%
df_down['source_path'] = pd.Series(dict((p.name[:11],str(p)) for p in source_file_paths))

# %%
df_down.source_path.str[20:]
# Out:
# ytid
# --4gqARaEJE           _eval_wav\Noise\Good\--4gqARaEJE_0.000.wav
# --BfvyPmVMo          _eval_wav\Noise\Good\--BfvyPmVMo_20.000.wav
# -0Gj8-vB1q4          _eval_wav\Music\Good\-0Gj8-vB1q4_30.000.wav
# -0RWZT-miFs          _eval_wav\Noise\Bad\-0RWZT-miFs_420.000.wav
# -0YUDn-1yII           _eval_wav\Music\Bad\-0YUDn-1yII_30.000.wav
#                                      ...
# QY_YNmYjUS8    _unbalanced_wav2\Speech\Unchecked\QY_YNmYjUS8_...
# QY_bTtoO0-c    _unbalanced_wav2\Speech\Unchecked\QY_bTtoO0-c_...
# QY_fLOyPXD4    _unbalanced_wav2\Speech\Unchecked\QY_fLOyPXD4_...
# QYaYLDEMarw    _unbalanced_wav2\Speech\Unchecked\QYaYLDEMarw_...
# QYbYwTz1ytA    _unbalanced_wav2\Speech\Unchecked\QYbYwTz1ytA_...
# Name: source_path, Length: 30309, dtype: object

# %%
df_down['destination_path'] = df_down.apply(lambda x: str(destination_path/x.check_status/x.dataset_split/x.plausible_superclass/x.name)+'.wav',axis=1)
df_down
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# QY_YNmYjUS8           30.0         40.0
# QY_bTtoO0-c           30.0         40.0
# QY_fLOyPXD4          200.0        210.0
# QYaYLDEMarw           30.0         40.0
# QYbYwTz1ytA          100.0        110.0
#
#                                      positive_labels     dataset_split  \
# ytid
# --4gqARaEJE  "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                               "/m/03l9g"              eval
# -0Gj8-vB1q4           "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                      "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                     "/m/02cjck,/m/04rlf"              eval
# ...

# %%
from tqdm import tqdm
import os
import shutil

for _, row in tqdm(df_down.iterrows()):
    os.makedirs(os.path.dirname(row.destination_path),exist_ok=True)
    shutil.copy(row.source_path, row.destination_path)
# Out:
# 30309it [14:14, 35.47it/s]

# %%
df_down.reset_index().to_json('processed/copied.json.gz',orient='records',indent=4)

# %% [markdown]
# # New downloadables

# %% [markdown]
# # Copy files Again

# %%
import pandas as pd
df_audioset = pd.read_json('processed/audioset_annot_4k.json.gz').set_index('ytid')
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
# ...                    ...          ...
# zzyyleHsxfk           20.0         30.0
# zzz-JsGPtxQ          120.0        130.0
# zzz3PZXRQ_8           30.0         40.0
# zzznDcamMpw            0.0         10.0
# zzztDPePp4g          410.0        420.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# --U7joUcTCo                                "/m/01b_21"              eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"              eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"              eval
# ...

# %%
from pathlib import Path
source_paths = list(Path(p) for p in [
                      'E:\\Dataspace\\Audioset\\down_train_unbalanced_0'
                      ])
source_file_paths = list(f for p in source_paths for f in p.rglob('*.wav'))
destination_path = Path('G:\\datasets\\audioset')
len(source_file_paths)
# Out:
# 53300

# %%
new_downloads = pd.Series(dict((p.name[:11],str(p)) for p in source_file_paths))
new_downloads
# Out:
# -a0Mr6g4r3k    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# -a2reKzNEjU    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# -a7bYYC9a44    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# -aaH3I2LHic    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# -aatIwCzLvs    E:\Dataspace\Audioset\down_train_unbalanced_0\...
#                                      ...
# __MxRgYZjSo    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# __qm75sFhZ4    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# __vER5Qryr0    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# __wtiVbl40M    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# ___lQJ20o4k    E:\Dataspace\Audioset\down_train_unbalanced_0\...
# Length: 53300, dtype: object

# %%
df_down = df_audioset.loc[new_downloads.index]
df_down = df_down.copy()
df_down
# Out:
#              start_seconds  end_seconds                positive_labels  \
# -a0Mr6g4r3k           30.0         40.0  "/m/07q2z82,/m/07yv9,/m/0k4j"
# -a2reKzNEjU           30.0         40.0           "/m/04rlf,/m/0l14gg"
# -a7bYYC9a44            0.0         10.0                     "/m/04rlf"
# -aaH3I2LHic           30.0         40.0                     "/m/04rlf"
# -aatIwCzLvs           30.0         40.0   "/m/0342h,/m/04rlf,/m/04szw"
# ...                    ...          ...                            ...
# __MxRgYZjSo           30.0         40.0                     "/m/09x0r"
# __qm75sFhZ4           10.0         20.0            "/m/04rlf,/m/0g293"
# __vER5Qryr0            3.0         13.0                     "/m/09x0r"
# __wtiVbl40M           30.0         40.0                     "/m/01m4t"
# ___lQJ20o4k           30.0         40.0                     "/m/0c1dj"
#
#                 dataset_split plausible_superclass  download_status  \
# ...

# %%
c1 = df_down.plausible_superclass.value_counts()
c1
# Out:
# speech    20958
# noise     17733
# music     14609
# Name: plausible_superclass, dtype: int64

# %%
c2 = df_audioset[(df_audioset.check_status=='unchecked') & (df_audioset.download_status)].plausible_superclass.value_counts()
c2
# Out:
# noise                    23238
# speech                   22691
# music                    20555
# other                    14493
# nonspeech_human_sound     1291
# Name: plausible_superclass, dtype: int64

# %%
c2.loc[c1.index] += c1
c2
# Out:
# other                    14493
# music                    20555
# noise                    23238
# speech                   22691
# nonspeech_human_sound     1291
# Name: plausible_superclass, dtype: int64

# %% [markdown]
# ## Add new downloads

# %%
df_audioset.loc[df_down.index,'download_status'] = True

# %% [markdown]
# ## Copy files

# %%
df_down['source_path'] = new_downloads

# %%
df_down.source_path.str[20:]
# Out:
# -a0Mr6g4r3k    t\down_train_unbalanced_0\-a0Mr6g4r3k_30.000.wav
# -a2reKzNEjU    t\down_train_unbalanced_0\-a2reKzNEjU_30.000.wav
# -a7bYYC9a44     t\down_train_unbalanced_0\-a7bYYC9a44_0.000.wav
# -aaH3I2LHic    t\down_train_unbalanced_0\-aaH3I2LHic_30.000.wav
# -aatIwCzLvs    t\down_train_unbalanced_0\-aatIwCzLvs_30.000.wav
#                                      ...
# __MxRgYZjSo    t\down_train_unbalanced_0\__MxRgYZjSo_30.000.wav
# __qm75sFhZ4    t\down_train_unbalanced_0\__qm75sFhZ4_10.000.wav
# __vER5Qryr0     t\down_train_unbalanced_0\__vER5Qryr0_3.000.wav
# __wtiVbl40M    t\down_train_unbalanced_0\__wtiVbl40M_30.000.wav
# ___lQJ20o4k    t\down_train_unbalanced_0\___lQJ20o4k_30.000.wav
# Name: source_path, Length: 53300, dtype: object

# %%
df_down['destination_path'] = df_down.apply(lambda x: str(destination_path/x.check_status/x.dataset_split/x.plausible_superclass/x.name)+'.wav',axis=1)
df_down
# Out:
#              start_seconds  end_seconds                positive_labels  \
# -a0Mr6g4r3k           30.0         40.0  "/m/07q2z82,/m/07yv9,/m/0k4j"
# -a2reKzNEjU           30.0         40.0           "/m/04rlf,/m/0l14gg"
# -a7bYYC9a44            0.0         10.0                     "/m/04rlf"
# -aaH3I2LHic           30.0         40.0                     "/m/04rlf"
# -aatIwCzLvs           30.0         40.0   "/m/0342h,/m/04rlf,/m/04szw"
# ...                    ...          ...                            ...
# __MxRgYZjSo           30.0         40.0                     "/m/09x0r"
# __qm75sFhZ4           10.0         20.0            "/m/04rlf,/m/0g293"
# __vER5Qryr0            3.0         13.0                     "/m/09x0r"
# __wtiVbl40M           30.0         40.0                     "/m/01m4t"
# ___lQJ20o4k           30.0         40.0                     "/m/0c1dj"
#
#                 dataset_split plausible_superclass  download_status  \
# ...

# %%
from tqdm import tqdm
import os
import shutil

for _, row in tqdm(df_down.iterrows(),total=len(df_down)):
    os.makedirs(os.path.dirname(row.destination_path),exist_ok=True)
    shutil.copy(row.source_path, row.destination_path)
# Out:
# 100%|██████████| 53300/53300 [20:57<00:00, 42.40it/s]

# %% [markdown]
# ## Save

# %%
df_down.reset_index().to_json('processed/new_copied.json.gz',orient='records',indent=4)
df_audioset.reset_index().to_json('processed/audioset_annot_4k.json.gz',orient='records',indent=4)

# %% [markdown]
# ## Save concise annotations

# %%
from pathlib import Path
import pandas as pd

base_path = Path(r'G:\datasets\audioset')

df_audioset = pd.read_json(str(base_path/'audioset_annot_4k.json.gz')).set_index('ytid')
df_audioset.head()
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
#
#                                        positive_labels dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"          eval
# --BfvyPmVMo                                 "/m/03l9g"          eval
# --U7joUcTCo                                "/m/01b_21"          eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"          eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"          eval
#
#               plausible_superclass  download_status check_status
# ytid
# --4gqARaEJE                  noise             True         good
# --BfvyPmVMo                  noise             True         good
# --U7joUcTCo  nonspeech_human_sound             True    unchecked
# ...

# %%
wav_files = list(base_path.rglob('*.wav'))
len(wav_files)
# Out:
# 83609

# %%
wav_file_paths = pd.Series(dict((wav_file.stem, wav_file.relative_to(base_path)) for wav_file in wav_files))
wav_file_paths.head()
# Out:
# -0YUDn-1yII    bad\eval\music\-0YUDn-1yII.wav
# -1UWSisR2zo    bad\eval\music\-1UWSisR2zo.wav
# -7YESdyyHVw    bad\eval\music\-7YESdyyHVw.wav
# -A1o1Egi20c    bad\eval\music\-A1o1Egi20c.wav
# -BAF0DHMqVA    bad\eval\music\-BAF0DHMqVA.wav
# dtype: object

# %%
df_audioset['wav_file_path'] = ''
df_audioset.loc[wav_file_paths.index, 'wav_file_path'] = wav_file_paths
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# --U7joUcTCo            0.0         10.0
# --i-y1v8Hy8            0.0          9.0
# -0BIyqJj9ZU           30.0         40.0
# ...                    ...          ...
# zzyyleHsxfk           20.0         30.0
# zzz-JsGPtxQ          120.0        130.0
# zzz3PZXRQ_8           30.0         40.0
# zzznDcamMpw            0.0         10.0
# zzztDPePp4g          410.0        420.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# --U7joUcTCo                                "/m/01b_21"              eval
# --i-y1v8Hy8  "/m/04rlf,/m/09x0r,/t/dd00004,/t/dd00005"              eval
# -0BIyqJj9ZU         "/m/07rgt08,/m/07sq110,/t/dd00001"              eval
# ...

# %%
df_audioset = df_audioset[df_audioset.plausible_superclass.isin(['noise','music','speech'])]
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# zzyiWF0F9sg           20.0         30.0
# zzyjKSkzyys           30.0         40.0
# zzyr6l8MetA           60.0         70.0
# zzyxEu9a2hw            0.0         10.0
# zzyyleHsxfk           20.0         30.0
#
#                                      positive_labels     dataset_split  \
# ytid
# --4gqARaEJE  "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                               "/m/03l9g"              eval
# -0Gj8-vB1q4           "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                      "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                     "/m/02cjck,/m/04rlf"              eval
# ...

# %%
df_audioset.download_status.value_counts()
# Out:
# False    1310570
# True       83609
# Name: download_status, dtype: int64

# %%
df_audioset = df_audioset[df_audioset.download_status]
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# zzfcNds_9_g           30.0         40.0
# zzlfP-snUeY           10.0         20.0
# zznhOWygvlo           20.0         30.0
# zzuMyRMw4h4           10.0         20.0
# zzvZ7CxKP7Y           60.0         70.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# -0Gj8-vB1q4             "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                        "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                       "/m/02cjck,/m/04rlf"              eval
# ...

# %%
df_audioset = df_audioset.drop(columns=['download_status'])
df_audioset
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# zzfcNds_9_g           30.0         40.0
# zzlfP-snUeY           10.0         20.0
# zznhOWygvlo           20.0         30.0
# zzuMyRMw4h4           10.0         20.0
# zzvZ7CxKP7Y           60.0         70.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# -0Gj8-vB1q4             "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                        "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                       "/m/02cjck,/m/04rlf"              eval
# ...

# %%
df_audioset = df_audioset.copy()
# df_audioset.reset_index().to_json('annotations.json.gz',orient='records',indent=4)
df_audioset.reset_index().to_csv('processed/annotations.csv',index=False)

# %%
df_audioset_test = pd.read_csv('processed/annotations.csv').set_index('ytid')
df_audioset_test
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# zzfcNds_9_g           30.0         40.0
# zzlfP-snUeY           10.0         20.0
# zznhOWygvlo           20.0         30.0
# zzuMyRMw4h4           10.0         20.0
# zzvZ7CxKP7Y           60.0         70.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# -0Gj8-vB1q4             "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                        "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                       "/m/02cjck,/m/04rlf"              eval
# ...
