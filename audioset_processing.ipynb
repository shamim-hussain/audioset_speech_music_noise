# %% [markdown]
# # Experiments

# %%
from pathlib import Path
import pandas as pd

base_path = Path(r'G:\datasets\audioset')

df_annot = pd.read_csv(base_path/'annotations.csv').set_index('ytid')
df_annot
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# zzfcNds_9_g           30.0         40.0
# zzlfP-snUeY           10.0         20.0
# zznhOWygvlo           20.0         30.0
# zzuMyRMw4h4           10.0         20.0
# zzvZ7CxKP7Y           60.0         70.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# -0Gj8-vB1q4             "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                        "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                       "/m/02cjck,/m/04rlf"              eval
# ...                                                ...               ...
# zzfcNds_9_g                                 "/m/09x0r"  train_unbalanced
# zzlfP-snUeY  "/m/02mk9,/m/07pb8fc,/m/07yv9,/t/dd00129"  train_unbalanced
# zznhOWygvlo                                 "/m/09x0r"  train_unbalanced
# zzuMyRMw4h4               "/m/01z5f,/m/0bt9lr,/m/0jbk"  train_unbalanced
# zzvZ7CxKP7Y            "/m/02p0sh1,/m/04rlf,/m/0l14gg"  train_unbalanced
#
#             plausible_superclass check_status  \
# ytid
# --4gqARaEJE                noise         good
# --BfvyPmVMo                noise         good
# -0Gj8-vB1q4                music         good
# -0RWZT-miFs                noise          bad
# -0YUDn-1yII                music          bad
# ...                          ...          ...
# zzfcNds_9_g               speech    unchecked
# zzlfP-snUeY                noise    unchecked
# zznhOWygvlo               speech    unchecked
# zzuMyRMw4h4                noise    unchecked
# zzvZ7CxKP7Y                music    unchecked
#
#                                                  wav_file_path
# ytid
# --4gqARaEJE                    good\eval\noise\--4gqARaEJE.wav
# --BfvyPmVMo                    good\eval\noise\--BfvyPmVMo.wav
# -0Gj8-vB1q4                    good\eval\music\-0Gj8-vB1q4.wav
# -0RWZT-miFs                     bad\eval\noise\-0RWZT-miFs.wav
# -0YUDn-1yII                     bad\eval\music\-0YUDn-1yII.wav
# ...                                                        ...
# zzfcNds_9_g  unchecked\train_unbalanced\speech\zzfcNds_9_g.wav
# zzlfP-snUeY   unchecked\train_unbalanced\noise\zzlfP-snUeY.wav
# zznhOWygvlo  unchecked\train_unbalanced\speech\zznhOWygvlo.wav
# zzuMyRMw4h4   unchecked\train_unbalanced\noise\zzuMyRMw4h4.wav
# zzvZ7CxKP7Y   unchecked\train_unbalanced\music\zzvZ7CxKP7Y.wav
#
# [83609 rows x 7 columns]

# %%
import librosa as rosa
import numpy as np
import matplotlib.pyplot as plt

sampling_rate = 22050

example_file = base_path/(df_annot.loc['zzfcNds_9_g', 'wav_file_path'])
example,_ = rosa.load(example_file, sr=sampling_rate, mono=True)

plt.plot(np.arange(len(example))/sampling_rate, example)

# %%
import sounddevice as sd
sd.play(example, sampling_rate)

# %% [markdown]
# ## Silence Removal

# %%
win_len = .025
win_step = .010

split_inds = rosa.effects.split(example, top_db=20, frame_length=int(win_len*sampling_rate), 
                            hop_length=int(win_step*sampling_rate))
split_inds
# Out:
# array([[  1100,   5940],
#        [ 12760,  25080],
#        [ 49280,  49500],
#        [ 49940,  51040],
#        [ 51920,  80080],
#        [ 82060,  91960],
#        [ 92180,  92620],
#        [ 98120, 103620],
#        [105160, 108900],
#        [109560, 110220],
#        [110660, 114840],
#        [115500, 118800],
#        [119680, 126940],
#        [127380, 132440],
#        [133100, 138380],
#        [139700, 143440],
#        [143880, 147620],
#        [148060, 150480],
#        [151360, 153780],
#        [154880, 155320],
#        [159720, 165000],
#        [166100, 167860],
#        [169400, 179080],
#        [179740, 185460],
#        [195360, 210760],
#        [211200, 215600]])

# %%
def remove_silence(audio, sampling_rate, top_db=20, win_len=.025, win_step=.010, return_silence=False):
    split_inds = rosa.effects.split(audio, top_db=top_db, frame_length=int(win_len*sampling_rate), 
                                    hop_length=int(win_step*sampling_rate))

    isig = np.concatenate(list(np.arange(*v) for v in split_inds), 0)
    signal = example[isig]
    if not return_silence:
        return signal
    else:
        isil = np.setdiff1d(np.arange(len(example)), isig)
        silence = example[isil]
        return signal, silence

# %%
import sounddevice as sd

signal, silence = remove_silence(example, sampling_rate, top_db=20, win_len=.025, win_step=.010, return_silence=True)
sd.play(signal, sampling_rate)

# %%
sd.play(silence, sampling_rate)

# %%
import tf_mel_features as tmf

specgram = tmf.log_spectrogram(signal, sampling_rate, win_len, win_step, 1024)
specgram
# Out:
# <tf.Tensor: shape=(667, 513), dtype=float32, numpy=
# array([[-25.244425 , -17.507551 , -15.696113 , ..., -13.669687 ,
#         -15.704737 , -17.36944  ],
#        [-19.220995 , -17.17994  , -14.63531  , ..., -17.345968 ,
#         -14.3996315, -14.905238 ],
#        [-13.355293 , -11.443407 , -12.928381 , ..., -16.831429 ,
#         -15.313528 , -13.99158  ],
#        ...,
#        [-17.843958 , -14.110123 , -15.701689 , ..., -13.747743 ,
#         -14.1783695, -17.233398 ],
#        [-15.653845 , -16.592897 , -14.239995 , ..., -15.623979 ,
#         -16.363731 , -15.349912 ],
#        [-17.18525  , -15.426716 , -17.817488 , ..., -16.626837 ,
#         -19.711536 , -19.452232 ]], dtype=float32)>

# %%
plt.matshow(specgram.numpy().T, origin='lower', aspect='auto')

# %%
import tensorflow as tf

example_tf, fs,  = tf.audio.decode_wav(tf.io.read_file(str(example_file)))
example_tf = tf.reduce_mean(example_tf, axis=1)

# %%
sd.play(example_tf.numpy(), fs.numpy())

# %%
import python_speech_features as psf
out = psf.logfbank(signal, sampling_rate, win_len, win_step, nfilt=64,nfft=1024)
out
# Out:
# array([[-17.5075946 , -14.75986727, -11.09337624, ...,  -9.72573012,
#          -9.766893  , -10.27625   ],
#        [-14.06681339, -13.65016684,  -9.98181362, ...,  -9.54635042,
#          -9.00012267,  -9.65575927],
#        [-12.03398393, -11.47027047, -10.1081625 , ...,  -9.59564498,
#          -8.96599173,  -9.7326888 ],
#        ...,
#        [-14.43380095, -13.18064404, -10.09842937, ..., -10.15199999,
#         -12.37731242, -11.27338898],
#        [-17.25107277, -13.77531496, -10.34073929, ..., -10.27575817,
#         -11.84050816, -11.83690108],
#        [-14.41963744, -13.8655378 , -11.02547926, ..., -10.86217386,
#         -11.78278024, -11.80774136]])

# %%
mfb = tmf.log_mfb(signal, sampling_rate, winlen=win_len, winstep=win_step, nfilt=64, nfft=1024)
mfb
# Out:
# (<tf.Tensor: shape=(667, 64), dtype=float32, numpy=
#  array([[-16.000975 , -13.265785 , -10.699541 , ...,  -9.737987 ,
#           -9.761899 , -10.2606535],
#         [-15.02408  , -12.160072 ,  -9.951225 , ...,  -9.622354 ,
#           -8.974079 ,  -9.524381 ],
#         [-11.617904 , -10.880156 , -10.495432 , ...,  -9.57001  ,
#           -8.926115 ,  -9.71046  ],
#         ...,
#         [-14.301755 , -11.396546 , -10.1852865, ..., -10.139657 ,
#          -12.215765 , -11.25727  ],
#         [-14.611809 , -11.862274 , -10.263132 , ..., -10.267136 ,
#          -11.822679 , -11.8412895],
#         [-15.706695 , -12.35506  , -11.28259  , ..., -10.879179 ,
#          -11.802646 , -11.799266 ]], dtype=float32)>,
#  <tf.Tensor: shape=(667,), dtype=float32, numpy=
#  array([0.01271671, 0.0145805 , 0.01569314, 0.01785268, 0.01895568,
#         0.02215201, 0.02631531, 0.02397384, 0.02157346, 0.02285455,
#         0.02274958, 0.02365788, 0.02221032, 0.01757525, 0.01649213,
#         0.01568514, 0.01361276, 0.00834204, 0.00473038, 0.00271037,
#         0.00271618, 0.01314935, 0.02636015, 0.04342272, 0.04609216,
#         0.0553676 , 0.04850934, 0.04668662, 0.04852255, 0.05112042,
#         0.04512405, 0.03581952, 0.02743327, 0.0168453 , 0.01336449,
#         0.01029007, 0.00813052, 0.00697714, 0.00646461, 0.00915518,
#         0.0140891 , 0.04126943, 0.11451427, 0.2257552 , 0.257864  ,
#         0.2334343 , 0.16874695, 0.08299118, 0.05003704, 0.0342406 ,
#         0.03016167, 0.03177135, 0.0343626 , 0.04543331, 0.06060616,
#         0.06896611, 0.06726486, 0.06526105, 0.06506221, 0.05821946,
#         0.045504  , 0.03273799, 0.02805787, 0.03332775, 0.03009965,
#         0.02793473, 0.02360401, 0.01799812, 0.0114603 , 0.03693262,
#         0.03829367, 0.01456032, 0.00862977, 0.00727347, 0.00640473,
#         0.00561621, 0.00435348, 0.03201276, 0.21014902, 0.35053432,
#         0.30817723, 0.14416803, 0.06319289, 0.07232691, 0.09189057,
#         0.08844721, 0.15157546, 0.14881673, 0.12617113, 0.13040504,
#         0.15750101, 0.2399452 , 0.2991225 , 0.44411856, 0.51807165,
#         0.52771556, 0.5875082 , 0.5764394 , 0.973988  , 0.9541718 ,
#         0.5359278 , 0.2906574 , 0.17107561, 0.11423372, 0.12320253,
#         0.11681372, 0.07766303, 0.06244522, 0.04734581, 0.03606022,
#         0.02819585, 0.02201676, 0.02055604, 0.02088846, 0.01790991,
#         0.01727926, 0.03895851, 0.06868745, 0.06471494, 0.04075306,
#         0.01089797, 0.01242128, 0.01221685, 0.00829399, 0.00938937,
#         0.01807113, 0.02388528, 0.01934122, 0.01314577, 0.0099529 ,
#         0.00636526, 0.00383782, 0.00333858, 0.00326824, 0.00359999,
#         0.01835103, 0.0507726 , 0.07293847, 0.18557873, 0.33201364,
#         0.3658617 , 0.22790757, 0.13286735, 0.10452335, 0.08472055,
#         0.06635143, 0.08885602, 0.38784158, 0.4561592 , 0.40866107,
#         0.2711086 , 0.24987212, 0.24645802, 0.20433451, 0.21787232,
#         0.22188973, 0.22731657, 0.20729926, 0.1865725 , 0.15333581,
#         0.09115595, 0.03940128, 0.025797  , 0.01705186, 0.02981458,
#         0.06967765, 0.08522055, 0.09891906, 0.09357928, 0.10791297,
#         0.13218525, 0.17149124, 0.22203673, 0.28048456, 0.3061655 ,
#         0.25953344, 0.21312392, 0.15316045, 0.12476195, 0.10567668,
#         0.08222849, 0.08109605, 0.11618823, 0.19919328, 0.31553096,
#         0.43958807, 0.5518254 , 0.7746659 , 0.9392216 , 0.7780527 ,
#         0.43113118, 0.18189529, 0.1591721 , 0.15785253, 0.13776407,
#         0.11135584, 0.08760898, 0.06860819, 0.09509965, 0.22973311,
#         0.4549595 , 0.60697   , 0.57380813, 0.72186023, 1.0049565 ,
#         0.9227375 , 0.6711631 , 0.2657175 , 0.12929712, 0.0824935 ,
#         0.05956043, 0.07610627, 0.0840321 , 0.08377093, 0.08485204,
#         0.08654362, 0.07929249, 0.05797967, 0.04852951, 0.05903587,
#         0.10425133, 0.15051721, 0.187821  , 0.23390241, 0.28090075,
#         0.28949088, 0.266241  , 0.27730942, 0.26730627, 0.21438128,
#         0.16350329, 0.07976469, 0.05625105, 0.03887663, 0.0288043 ,
#         0.0161112 , 0.01373953, 0.01341642, 0.01211181, 0.01115252,
#         0.01031968, 0.00864044, 0.00884025, 0.00825187, 0.00847085,
#         0.00871125, 0.00959196, 0.01170163, 0.01211598, 0.010106  ,
#         0.00673536, 0.00310574], dtype=float32)>)

# %%
plt.matshow(mfb[0].numpy().T, origin='lower', aspect='auto')

# %%
plt.matshow(out.T, origin='lower', aspect='auto')

# %%
out.dtype

# %%
import python_speech_features as psf

def normalize_volume(sig, fs, winlen=.200, winstep=.010):
    frms = psf.sigproc.framesig(sig, winlen*fs, winstep*fs)
    frms = frms/frms.std(axis=-1, keepdims=True)
    sig = psf.sigproc.deframesig(frms, siglen=len(sig), 
                                  frame_len=winlen*fs, frame_step= winstep*fs)
    return sig

# %%
normalized_signal = normalize_volume(signal, sampling_rate)
sd.play(normalized_signal, sampling_rate)

# %%
out_norm = psf.logfbank(normalized_signal, sampling_rate, win_len, win_step, nfilt=64,nfft=1024)
plt.matshow(out_norm.T, origin='lower', aspect='auto')
plt.matshow(out.T, origin='lower', aspect='auto')

# %%
sampling_rate
# Out:
# 22050

# %% [markdown]
# # Process Files

# %%
from pathlib import Path
import pandas as pd

base_path = Path(r'G:\datasets\audioset')
feat_path = r'features\logmfb'

df_annot = pd.read_csv(base_path/'annotations.csv').set_index('ytid')
df_annot
# Out:
#              start_seconds  end_seconds  \
# ytid
# --4gqARaEJE            0.0         10.0
# --BfvyPmVMo           20.0         30.0
# -0Gj8-vB1q4           30.0         40.0
# -0RWZT-miFs          420.0        430.0
# -0YUDn-1yII           30.0         40.0
# ...                    ...          ...
# zzfcNds_9_g           30.0         40.0
# zzlfP-snUeY           10.0         20.0
# zznhOWygvlo           20.0         30.0
# zzuMyRMw4h4           10.0         20.0
# zzvZ7CxKP7Y           60.0         70.0
#
#                                        positive_labels     dataset_split  \
# ytid
# --4gqARaEJE    "/m/068hy,/m/07q6cd_,/m/0bt9lr,/m/0jbk"              eval
# --BfvyPmVMo                                 "/m/03l9g"              eval
# -0Gj8-vB1q4             "/m/0140xf,/m/02cjck,/m/04rlf"              eval
# -0RWZT-miFs                        "/m/03v3yw,/m/0k4j"              eval
# -0YUDn-1yII                       "/m/02cjck,/m/04rlf"              eval
# ...                                                ...               ...
# zzfcNds_9_g                                 "/m/09x0r"  train_unbalanced
# zzlfP-snUeY  "/m/02mk9,/m/07pb8fc,/m/07yv9,/t/dd00129"  train_unbalanced
# zznhOWygvlo                                 "/m/09x0r"  train_unbalanced
# zzuMyRMw4h4               "/m/01z5f,/m/0bt9lr,/m/0jbk"  train_unbalanced
# zzvZ7CxKP7Y            "/m/02p0sh1,/m/04rlf,/m/0l14gg"  train_unbalanced
#
#             plausible_superclass check_status  \
# ytid
# --4gqARaEJE                noise         good
# --BfvyPmVMo                noise         good
# -0Gj8-vB1q4                music         good
# -0RWZT-miFs                noise          bad
# -0YUDn-1yII                music          bad
# ...                          ...          ...
# zzfcNds_9_g               speech    unchecked
# zzlfP-snUeY                noise    unchecked
# zznhOWygvlo               speech    unchecked
# zzuMyRMw4h4                noise    unchecked
# zzvZ7CxKP7Y                music    unchecked
#
#                                                  wav_file_path
# ytid
# --4gqARaEJE                    good\eval\noise\--4gqARaEJE.wav
# --BfvyPmVMo                    good\eval\noise\--BfvyPmVMo.wav
# -0Gj8-vB1q4                    good\eval\music\-0Gj8-vB1q4.wav
# -0RWZT-miFs                     bad\eval\noise\-0RWZT-miFs.wav
# -0YUDn-1yII                     bad\eval\music\-0YUDn-1yII.wav
# ...                                                        ...
# zzfcNds_9_g  unchecked\train_unbalanced\speech\zzfcNds_9_g.wav
# zzlfP-snUeY   unchecked\train_unbalanced\noise\zzlfP-snUeY.wav
# zznhOWygvlo  unchecked\train_unbalanced\speech\zznhOWygvlo.wav
# zzuMyRMw4h4   unchecked\train_unbalanced\noise\zzuMyRMw4h4.wav
# zzvZ7CxKP7Y   unchecked\train_unbalanced\music\zzvZ7CxKP7Y.wav
#
# [83609 rows x 7 columns]

# %%
import librosa as rosa
import python_speech_features as psf
import numpy as np



def load_audio(file_path, sampling_rate = 22050):
    audio, _ = rosa.load(file_path, sr=sampling_rate, mono=True)
    return audio

def remove_silence(audio, sampling_rate=22050, top_db=20, win_len=.025, win_step=.010, return_silence=False):
    split_inds = rosa.effects.split(audio, top_db=top_db, frame_length=int(win_len*sampling_rate), 
                                    hop_length=int(win_step*sampling_rate))

    isig = np.concatenate(list(np.arange(*v) for v in split_inds), 0)
    signal = audio[isig]
    if not return_silence:
        return signal
    else:
        isil = np.setdiff1d(np.arange(len(audio)), isig)
        silence = audio[isil]
        return signal, silence

def normalize_volume(sig, sampling_rate=22050, win_len=.200, win_step=.010):
    frms = psf.sigproc.framesig(sig, win_len*sampling_rate, win_step*sampling_rate)
    frms = frms/frms.std(axis=-1, keepdims=True)
    sig = psf.sigproc.deframesig(frms, siglen=len(sig), 
                                  frame_len=win_len*sampling_rate, frame_step= win_step*sampling_rate)
    return sig


def get_features(audio, sampling_rate=22050, win_len=.025, win_step=.010, nfilt=64, nfft=1024):
    mfb = psf.logfbank(audio, sampling_rate, win_len, win_step, nfilt, nfft)
    return mfb


def process_file(file_path, sampling_rate=22050, win_len=.025, win_step=.010, nfilt=64, nfft=1024, dtype=np.float32):
    audio = load_audio(file_path, sampling_rate)
    signal = remove_silence(audio, sampling_rate)
    normalized_signal = normalize_volume(signal, sampling_rate)
    mfb = get_features(normalized_signal, sampling_rate, win_len, win_step, nfilt, nfft).astype(dtype)
    return mfb

# %%
example_file = base_path/(df_annot.loc['zzfcNds_9_g', 'wav_file_path'])
processed_example = process_file(example_file)
processed_example
# Out:
# array([[-11.387638 ,  -8.632347 ,  -4.962714 , ...,  -3.5938842,
#          -3.6332471,  -4.1442237],
#        [ -7.9221487,  -7.509336 ,  -3.8460438, ...,  -3.4076676,
#          -2.8585231,  -3.5167062],
#        [ -5.900443 ,  -5.338427 ,  -3.9622135, ...,  -3.449924 ,
#          -2.820202 ,  -3.5908222],
#        ...,
#        [ -7.342895 ,  -6.0899506,  -3.0072653, ...,  -3.0608578,
#          -5.2860885,  -4.1828203],
#        [-10.159366 ,  -6.683041 ,  -3.2474794, ...,  -3.1819541,
#          -4.7453365,  -4.742112 ],
#        [ -7.325352 ,  -6.770846 ,  -3.9297352, ...,  -3.7656782,
#          -4.6895185,  -4.715775 ]], dtype=float32)

# %%
from tqdm import tqdm

df_selected = df_annot.loc[df_annot.check_status == 'good']
df_annot['logmfb_path'] = ''

for ytid, row in tqdm(df_selected.iterrows(), total=len(df_selected)):
    file_path = base_path/row.wav_file_path
    
    features = process_file(file_path)
    
    dest_path = base_path/feat_path/row.check_status/row.dataset_split/row.plausible_superclass/(ytid+'.npy')
    
    dest_path.parent.mkdir(parents=True, exist_ok=True)
    np.save(str(dest_path), features)
    
    df_annot.loc[ytid, 'logmfb_path'] = str(dest_path)
# Out:
# 100%|██████████| 12064/12064 [43:18<00:00,  4.64it/s]

# %%
df_annot.loc[:,['logmfb_path']].reset_index()
# Out:
#               ytid                                        logmfb_path
# 0      --4gqARaEJE  G:\datasets\audioset\features\logmfb\good\eval...
# 1      --BfvyPmVMo  G:\datasets\audioset\features\logmfb\good\eval...
# 2      -0Gj8-vB1q4  G:\datasets\audioset\features\logmfb\good\eval...
# 3      -0RWZT-miFs
# 4      -0YUDn-1yII
# ...            ...                                                ...
# 83604  zzfcNds_9_g
# 83605  zzlfP-snUeY
# 83606  zznhOWygvlo
# 83607  zzuMyRMw4h4
# 83608  zzvZ7CxKP7Y
#
# [83609 rows x 2 columns]
